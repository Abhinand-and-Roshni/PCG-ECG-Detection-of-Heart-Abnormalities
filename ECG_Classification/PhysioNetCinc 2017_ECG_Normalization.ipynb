# %%
from sklearn import preprocessing
import pandas as pd
import numpy as np

# %%
unscaled_df = pd.read_csv("PHSYIONET2017_ECG_FEATURES(before normalization).csv")
unscaled_df.head()
# Out:
#   file_name  HYPOTHESIS  full_waveform_min  full_waveform_max  \
# 0    A00001           1          -0.405281           1.121756
# 1    A00002           1          -0.954112           2.627004
# 2    A00003           1          -0.632330           1.404153
# 3    A00004          -1          -0.295871           1.097179
# 4    A00005          -1          -0.766196           1.196451
#
#    full_waveform_mean  full_waveform_median  full_waveform_std  \
# 0            0.001065             -0.006663           0.179318
# 1            0.001680             -0.005670           0.217056
# 2            0.000763             -0.015898           0.201006
# 3            0.002550             -0.006243           0.148257
# 4            0.000772             -0.008146           0.192305
#
#    full_waveform_skew  full_waveform_kurtosis  full_waveform_duration  ...  \
# 0            3.195531               14.631998               29.996667  ...
# ...

# %%
#unscaled_df = unscaled_df.drop(['file_name'], axis = 1)
unscaled_df = unscaled_df.drop(['label_y'], axis = 1)

# %%
unscaled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8244 entries, 0 to 8243
# Data columns (total 87 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   HYPOTHESIS                8244 non-null   float64
#  1   full_waveform_min         8244 non-null   float64
#  2   full_waveform_max         8244 non-null   float64
#  3   full_waveform_mean        8244 non-null   float64
#  4   full_waveform_median      8244 non-null   float64
#  5   full_waveform_std         8244 non-null   float64
#  6   full_waveform_skew        8244 non-null   float64
#  7   full_waveform_kurtosis    8244 non-null   float64
#  8   full_waveform_duration    8244 non-null   float64
#  9   swt_d_1_low_power_ratio   8244 non-null   float64
#  10  swt_d_1_med_power_ratio   8244 non-null   float64
#  11  swt_d_1_high_power_ratio  8244 non-null   float64
#  12  swt_a_1_low_power_ratio   8244 non-null   float64
# ...

# %%
df_min_max_scaled = unscaled_df
  
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = ((df_min_max_scaled[column] - df_min_max_scaled[column].min())) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
df_min_max_scaled.head()
# Out:
#    HYPOTHESIS  full_waveform_min  full_waveform_max  full_waveform_mean  \
# 0         1.0           0.993487           0.003219            0.604295
# 1         1.0           0.972524           0.049807            0.618282
# 2         1.0           0.984815           0.011960            0.597411
# 3         0.0           0.997666           0.002459            0.638051
# 4         0.0           0.979702           0.005531            0.597618
#
#    full_waveform_median  full_waveform_std  full_waveform_skew  \
# 0              0.672162           0.068068            0.583659
# 1              0.677035           0.100452            0.605290
# 2              0.626847           0.086679            0.570433
# 3              0.674225           0.041413            0.617288
# 4              0.664885           0.079212            0.574957
#
#    full_waveform_kurtosis  full_waveform_duration  swt_d_1_low_power_ratio  \
# ...

# %%
df = df_min_max_scaled

# %%
df.describe()
# Out:
#         HYPOTHESIS  full_waveform_min  full_waveform_max  full_waveform_mean  \
# count  8244.000000        8244.000000        8244.000000         8244.000000
# mean      0.612567           0.968600           0.014891            0.599023
# std       0.487194           0.048018           0.035654            0.035510
# min       0.000000           0.000000           0.000000            0.000000
# 25%       0.000000           0.966627           0.002948            0.584525
# 50%       1.000000           0.981867           0.005106            0.599224
# 75%       1.000000           0.990217           0.010704            0.612759
# max       1.000000           1.000000           1.000000            1.000000
#
#        full_waveform_median  full_waveform_std  full_waveform_skew  \
# count           8244.000000        8244.000000         8244.000000
# mean               0.666829           0.082670            0.560660
# std                0.037960           0.061978            0.052655
# ...

# %%
df['HYPOTHESIS'] = unscaled_df['HYPOTHESIS']
df
# Out:
#       HYPOTHESIS  full_waveform_min  full_waveform_max  full_waveform_mean  \
# 0            1.0           0.993487           0.003219            0.604295
# 1            1.0           0.972524           0.049807            0.618282
# 2            1.0           0.984815           0.011960            0.597411
# 3            0.0           0.997666           0.002459            0.638051
# 4            0.0           0.979702           0.005531            0.597618
# ...          ...                ...                ...                 ...
# 8239         1.0           0.992098           0.002714            0.613495
# 8240         0.0           0.983942           0.003291            0.708200
# 8241         1.0           0.981500           0.004831            0.593219
# 8242         1.0           0.977387           0.063898            0.571219
# 8243         1.0           0.983800           0.006045            0.570615
#
#       full_waveform_median  full_waveform_std  full_waveform_skew  \
# ...

# %%
df.to_csv("NORMALIZED_PHYSIONET_2017_ECG_FEATURES.csv")

# %%
df['HYPOTHESIS'].value_counts()
# Out:
# 1.0    5050
# 0.0    3194
# Name: HYPOTHESIS, dtype: int64

# %%
############### CIRCOR DATASET

# %%
import pandas as pd

# %%
unscaled_circor = pd.read_csv('C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION.csv')

# %%
unscaled_circor = unscaled_circor.drop(['PatientID', 'Class', 'RecordID', 'Valves'], axis = 1)
unscaled_circor
# Out:
#       Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# 0             -1       0.154100            1.98830          0.15562
# 1             -1       0.174160            1.77790          0.25657
# 2             -1       0.227410            1.98230          0.22067
# 3             -1       0.206520            1.92000          0.24852
# 4             -1       0.188910            2.11350          0.51308
# ...          ...            ...                ...              ...
# 3158          -1       0.050003            0.51017          0.11887
# 3159          -1       0.148420            2.00050          0.48702
# 3160          -1       0.137010            2.21700          0.37344
# 3161          -1       0.121700            2.31650          0.36703
# 3162          -1       0.129810            2.26270          0.38500
#
#       PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency  BandPower  \
# 0           0.000132                   15014.0        0.22275   0.002648
# ...

# %%
us = unscaled_circor
us.describe()
# Out:
#         Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# count  3163.000000    3163.000000        3163.000000      3163.000000
# mean      0.031932       0.162158           2.124582         0.405325
# std       0.999648       0.064441           0.361223         0.287032
# min      -1.000000       0.035426           0.510170         0.062172
# 25%      -1.000000       0.115990           1.928900         0.176565
# 50%       1.000000       0.153200           2.210400         0.328720
# 75%       1.000000       0.197125           2.396200         0.540875
# max       1.000000       0.597270           2.725500         1.970100
#
#        PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency    BandPower  \
# count     3163.000000              3.163000e+03    3163.000000  3163.000000
# mean         0.000213              1.010036e+09       0.525611     0.004065
# std          0.000846              5.285086e+10       0.246206     0.010875
# ...

# %%
df_min_max_scaled = unscaled_circor
  
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = ((df_min_max_scaled[column] - df_min_max_scaled[column].min())) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
df_min_max_scaled.head()
# Out:
#    Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# 0         0.0       0.211222           0.667228         0.048979
# 1         0.0       0.246926           0.572253         0.101890
# 2         0.0       0.341703           0.664520         0.083073
# 3         0.0       0.304522           0.636397         0.097670
# 4         0.0       0.273179           0.723743         0.236334
#
#    PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency  BandPower  \
# 0        0.008772              5.050270e-09       0.066617   0.015756
# 1        0.002106              2.427604e-06       0.213589   0.007250
# 2        0.006234              8.181813e-06       0.139012   0.011445
# 3        0.006842              6.821559e-10       0.134046   0.014207
# 4        0.002106              2.143714e-08       0.320851   0.008693
#
#    RootSumSquare  Peak2PeakDifference  ...    MFCC30    MFCC31    MFCC32  \
# 0       0.062737             1.000000  ...  0.790903  0.665262  0.720777
# ...

# %%
df = df_min_max_scaled

# %%
df.describe()
# Out:
#         Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# count  3163.000000    3163.000000        3163.000000      3163.000000
# mean      0.515966       0.225564           0.728746         0.179857
# std       0.499824       0.114695           0.163056         0.150442
# min       0.000000       0.000000           0.000000         0.000000
# 25%       0.000000       0.143392           0.640415         0.059957
# 50%       1.000000       0.209620           0.767484         0.139705
# 75%       1.000000       0.287801           0.851354         0.250902
# max       1.000000       1.000000           1.000000         1.000000
#
#        PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency    BandPower  \
# count     3163.000000              3.163000e+03    3163.000000  3163.000000
# mean         0.014329              3.400793e-04       0.251361     0.024370
# std          0.058377              1.779490e-02       0.150184     0.066154
# ...

# %%
df['Hypothesis'] = us['Hypothesis']
df.to_csv('C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_NORMALIZED.csv')

# %%
df
# Out:
#       Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# 0             -1       0.211222           0.667228         0.048979
# 1             -1       0.246926           0.572253         0.101890
# 2             -1       0.341703           0.664520         0.083073
# 3             -1       0.304522           0.636397         0.097670
# 4             -1       0.273179           0.723743         0.236334
# ...          ...            ...                ...              ...
# 3158          -1       0.025945           0.000000         0.029717
# 3159          -1       0.201113           0.672735         0.222675
# 3160          -1       0.180805           0.770463         0.163145
# 3161          -1       0.153555           0.815377         0.159785
# 3162          -1       0.167990           0.791092         0.169203
#
#       PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency  BandPower  \
# 0           0.008772              5.050270e-09       0.066617   0.015756
# ...

# %%
us
# Out:
#       Hypothesis  ZeroCrossRate  OccupiedBandwidth  MedianFrequency  \
# 0             -1       0.154100            1.98830          0.15562
# 1             -1       0.174160            1.77790          0.25657
# 2             -1       0.227410            1.98230          0.22067
# 3             -1       0.206520            1.92000          0.24852
# 4             -1       0.188910            2.11350          0.51308
# ...          ...            ...                ...              ...
# 3158          -1       0.050003            0.51017          0.11887
# 3159          -1       0.148420            2.00050          0.48702
# 3160          -1       0.137010            2.21700          0.37344
# 3161          -1       0.121700            2.31650          0.36703
# 3162          -1       0.129810            2.26270          0.38500
#
#       PowerBandwidth  EquivalentNoiseBandwidth  MeanFrequency  BandPower  \
# 0           0.000132                   15014.0        0.22275   0.002648
# ...

# %%
unscaled_circor = pd.read_csv('C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION.csv')

# %%
unscaled_circor.loc[unscaled_circor["Hypothesis"] == -1, "Hypothesis"] = "Abnormal"
unscaled_circor.loc[unscaled_circor["Hypothesis"] == 1, "Hypothesis"] = "Normal"

unscaled_circor['Hypothesis'].value_counts()
# Out:
# Normal      1632
# Abnormal    1531
# Name: Hypothesis, dtype: int64

# %%
unscaled_circor['Valves'].value_counts()
# Out:
# MV     870
# AV     787
# PV     783
# TV     721
# Phc      2
# Name: Valves, dtype: int64

# %%
df_MV = unscaled_circor[unscaled_circor['Valves'] == 'MV']
df_AV = unscaled_circor[unscaled_circor['Valves'] == 'AV']
df_PV = unscaled_circor[unscaled_circor['Valves'] == 'PV']
df_TV = unscaled_circor[unscaled_circor['Valves'] == 'TV']
df_Phc = unscaled_circor[unscaled_circor['Valves'] == 'Phc']

# %%
df_MV.to_csv("C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION_only-MV.csv", index = False)
df_AV.to_csv("C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION_only-AV.csv", index = False)
df_PV.to_csv("C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION_only-PV.csv", index = False)
df_TV.to_csv("C:/Users/Roshni/OneDrive/Desktop/Sem7/Project 1/PREPROCESSING- POSTREVIEW1/circor/CirCor_BEFORE_NORMALIZATION_only-TV.csv", index = False)
